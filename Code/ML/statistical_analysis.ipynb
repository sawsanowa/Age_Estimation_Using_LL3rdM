# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler,OrdinalEncoder,LabelBinarizer

# %%
df = pd.read_csv('/content/all_updated.csv')

df.drop(['code','age'], axis='columns', inplace=True)

print(df)

# %%
df.dtypes
# Out:
# gender       float64
# apex1        float64
# apex2        float64
# height       float64
# Index        float64
# age_group     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   gender     487 non-null    float64
#  1   apex1      487 non-null    float64
#  2   apex2      487 non-null    float64
#  3   height     487 non-null    float64
#  4   Index      487 non-null    float64
#  5   age_group  487 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 23.0+ KB

# %%
df.describe()
# Out:
#             apex1       apex2      height       Index
# count  487.000000  487.000000  487.000000  487.000000
# mean     1.040657    1.947023   14.123203    0.292418
# std      1.366542    2.144566    3.836083    0.341546
# min     -1.000000    0.000000    2.500000    0.000000
# 25%      0.000000    0.200000   11.500000    0.027875
# 50%      0.800000    1.300000   14.600000    0.160256
# 75%      1.900000    2.800000   16.700000    0.442026
# max      8.000000   10.000000   26.000000    1.956522

# %%
df.shape
# Out:
# (487, 6)

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Making a correlation plot - to view the correlation between features
sns.heatmap(df.corr(), annot=True, cmap='BuPu') #cmap = 'Reds'

# %%
#df['age_group'] = df.age_group.map({'adult':0.0, 'minor':1.0}) 
#df

# %%
# Visualizing the age feature - balanced data set
df['age_group'].value_counts().plot(kind='bar')
plt.ylabel("Total", fontsize = 12)
plt.xlabel('Age Group')
df.age_group.value_counts()
# Out:
# adult    286
# minor    201
# Name: age_group, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar')
plt.ylabel("Total", fontsize = 12)
plt.xlabel('Gender')
df.gender.value_counts()
# Out:
# 0.0    256
# 1.0    231
# Name: gender, dtype: int64

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(df, hue="age_group", height=3);
plt.show()

# %%
df.drop('age_group', axis=1).plot(kind='box', subplots=True, layout=(5,5), sharex=False, sharey=False, figsize=(12,15), 
                                        title='Box Plot for each input variable')
#plt.savefig('age_boxplot')
plt.show()

# %%
df.drop('age_group' ,axis=1).hist(bins=30, figsize=(9,9))
#plt.suptitle("Histogram for each numeric input variable")
#plt.savefig('age_group')
plt.show()

# %%
scatter_matrix(df.drop('age_group', axis=1), figsize=(12, 9))
plt.show()
